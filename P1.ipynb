# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, consult the forums for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def mask_color(image, rgb_threshold = [0,0,0]):
    # Mask pixels below the threshold
    color_thresholds = (image[:,:,0] < rgb_threshold[0]) | \
                    (image[:,:,1] < rgb_threshold[1]) | \
                    (image[:,:,2] < rgb_threshold[2])
    color_select = np.copy(image)
    color_select[color_thresholds] = [0,0,0]
    
    return color_select
    

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    `vertices` should be a numpy array of integer points.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    left_lines = []
    right_lines = []
    lines_to_draw = []
    y_mid = 310
    for line in lines:
        # print(line)
        for x1,y1,x2,y2 in line:
            # Commented out original line draw func
            # cv2.line(img, (x1, y1), (x2, y2), color, thickness)
            slope = (y2-y1)/(x2-x1)
            b = y1 - x1*slope
            # The x value if we extrapolate to bottom of the image
            x_bot = (img.shape[1]-b) / slope
            print("Line: slope={slope}, b={b}, xbot={xbot}".format(slope=slope,b=b,xbot=x_bot))
            is_left_lane = slope < 0 and b > img.shape[1] and x_bot < img.shape[0]/2 and x_bot > 0
            is_right_lane = slope > 0 and b < 0 and x_bot > img.shape[0]/2 and x_bot < img.shape[0]
            print("Is Left: {l}, Is Right: {r}".format(l=is_left_lane, r=is_right_lane))
            if is_left_lane or is_right_lane:
                x_mid = slope * y_mid + b 
                x1,y1,x2,y2 = (x_bot,image.shape[1], x_mid, y_mid)
                cv2.line(img, (x1, y1), (x2, y2), color, thickness)
            

            
def find_lane_lines(lines):
    """
    Given a list of lines
    Find two lane lines and return them
    """
    lines_with_params = []
    for line in lines:
        for x1,y1,x2,y2 in line:
            m = (y2-y1)/(x2-x1)
            b = y1 - x1 * m 
            theta = np.arctan(m)
            lines_with_params.append({'m':m,'b':b, 'theta':theta, 'line':line})
    
    # todo(qingyouzhao): make this sorted so we don't need O(n2) in practice
    lines_with_params = sorted(lines_with_params, key=lambda line: line['theta'])
    # group the lines by slope
    theta_threshold = np.pi * 5 / 180
    b_threshold = 5
    for line2 in lines_with_params:
        # for each param, iterate through all other lines and find a most concatenated line
        candidate_lines = [line2 ]
        for line1 in lines_with_params:
            slope_is_close = line1['theta'] - line2['theta'] < theta_threshold
            b_is_close = line1['b'] - line2['b'] < b_threshold
            if slope_is_close and b_is_close:
                candidate_lines.append(line1)
        
        # Extrapolate and combine to lower lane
        for line in candidate_lines:
            pass
    
    # Then parse with some heuristics
    
    return lines
    

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    find_lane_lines(lines)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., γ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + γ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, γ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images_output directory.
def draw_lane_lines(img):
    """
    Given a image. Output a image that have lane line rendered on the image
    This is achieved in the following pipeline
    1. convert img to greyscale
    2. Apply Gaussian and Canny filter to output a canny edge
    3. Find line segments as lanes in the Canny image with Hough Transform
    4. Renbder lanes found as red on the original image  
    params
    img: image to mark
    return values
    
    """
    img_with_lane_line = np.zeros_like(img)
    
    # fist we want to mask out the darker side
    masked_img = mask_color(img, [180,180,0])
    # return masked_img
    # convert to grey scale
    grey = grayscale(masked_img)

    # blur with a gaussian filter
    kernel_size = 5
    blurred_grey = gaussian_blur(grey, kernel_size)
    
    # edge detect with Canny
    low_threshold = 100
    high_threshold = 150
    edges = canny(blurred_grey, low_threshold, high_threshold)
    
    # This time we are defining a four sided polygon to mask
    imshape = img.shape
    vertices = np.array([[(0,imshape[0]),(450, 310), (490, 310), (imshape[1],imshape[0])]], dtype=np.int32)
    masked_edges = region_of_interest(edges, vertices)
    
    # line detection from masked edges
    rho = 1
    theta = np.pi*2/180
    threshold = 5
    min_line_length = 10
    max_line_gap = 5
    img_with_lane_line = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)
        
    img_with_lane_line = weighted_img(img_with_lane_line, img, α=0.8, β=1., γ=0.)
    
    return img_with_lane_line
    
test_images = os.listdir("test_images/")

for image_file in test_images:
    img = mpimg.imread('test_images/{0}'.format(image_file))
    mpimg.imsave('test_images_output/{0}'.format(image_file), draw_lane_lines(img))
# Out:
# Line: slope=0.5423728813559322, b=50.84745762711867, xbot=1676.2499999999998
# Is Left: False, Is Right: False
# Line: slope=0.6101694915254238, b=5.0677966101694665, xbot=1565.0277777777778
# Is Left: False, Is Right: False
# Line: slope=0.5652173913043478, b=33.608695652173935, xbot=1639.0
# Is Left: False, Is Right: False
# Line: slope=0.5394736842105263, b=53.64473684210526, xbot=1680.0731707317075
# Is Left: False, Is Right: False
# Line: slope=0.5684210526315789, b=33.30526315789473, xbot=1630.2962962962963
# Is Left: False, Is Right: False
# Line: slope=-0.7, b=651.3, xbot=-441.0000000000001
# Is Left: False, Is Right: False
# Line: slope=0.5434782608695652, b=51.67391304347825, xbot=1671.3200000000002
# Is Left: False, Is Right: False
# Line: slope=0.5, b=80.5, xbot=1759.0
# Is Left: False, Is Right: False
# Line: slope=-0.8333333333333334, b=705.3333333333334, xbot=-305.59999999999997
# Is Left: False, Is Right: False
# Line: slope=-0.8888888888888888, b=712.8888888888889, xbot=-278.0
# Is Left: False, Is Right: False
# Line: slope=0.5370370370370371, b=56.277777777777715, xbot=1682.7931034482758
# Is Left: False, Is Right: False
# Line: slope=0.6078431372549019, b=8.235294117647072, xbot=1565.8064516129034
# Is Left: False, Is Right: False
# Line: slope=0.5645161290322581, b=34.64516129032256, xbot=1639.1999999999998
# Is Left: False, Is Right: False
# Line: slope=0.5, b=82.0, xbot=1756.0
# Is Left: False, Is Right: False
# Line: slope=0.5454545454545454, b=53.54545454545456, xbot=1661.8333333333335
# Is Left: False, Is Right: False
# Line: slope=0.6923076923076923, b=-66.0, xbot=1482.0
# Is Left: False, Is Right: False
# Line: slope=0.5, b=87.0, xbot=1746.0
# Is Left: False, Is Right: False
# Line: slope=-0.9, b=713.8, xbot=-273.5555555555556
# Is Left: False, Is Right: False
# Line: slope=0.5384615384615384, b=57.769230769230774, xbot=1675.5714285714287
# Is Left: False, Is Right: False
# Line: slope=-0.7272727272727273, b=662.3636363636364, xbot=-409.25
# Is Left: False, Is Right: False
# Line: slope=0.5, b=79.5, xbot=1761.0
# Is Left: False, Is Right: False
# Line: slope=-0.7368421052631579, b=664.2105263157895, xbot=-401.42857142857144
# Is Left: False, Is Right: False
# Line: slope=0.5, b=79.0, xbot=1762.0
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-42.33333333333326, xbot=1503.5
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-43.33333333333326, xbot=1505.0
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-45.0, xbot=1507.5
# Is Left: False, Is Right: False
# Line: slope=0.5, b=85.0, xbot=1750.0
# Is Left: False, Is Right: False
# Line: slope=0.5, b=80.0, xbot=1760.0
# Is Left: False, Is Right: False
# Line: slope=0.0, b=462.0, xbot=inf
# Is Left: False, Is Right: False
# Line: slope=0.8, b=-86.0, xbot=1307.5
# Is Left: False, Is Right: False
# Line: slope=0.0, b=319.0, xbot=inf
# Is Left: False, Is Right: False
# Line: slope=0.6153846153846154, b=-7.0, xbot=1571.375
# Is Left: False, Is Right: False
# Line: slope=0.47058823529411764, b=99.64705882352939, xbot=1828.25
# Is Left: False, Is Right: False
# Line: slope=-0.8823529411764706, b=722.7058823529412, xbot=-268.9333333333333
# Is Left: False, Is Right: False
# Line: slope=0.26666666666666666, b=208.53333333333333, xbot=2818.0
# Is Left: False, Is Right: False
# Line: slope=0.5454545454545454, b=51.363636363636374, xbot=1665.8333333333335
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=643.6666666666666, xbot=-474.50000000000006
# Is Left: False, Is Right: False
# Line: slope=0.46153846153846156, b=109.84615384615381, xbot=1842.0
# Is Left: False, Is Right: False
# Line: slope=-0.8, b=696.2, xbot=-329.74999999999994
# Is Left: False, Is Right: False
# Line: slope=0.5, b=81.5, xbot=1757.0
# Is Left: False, Is Right: False
# Line: slope=0.5714285714285714, b=35.428571428571445, xbot=1618.0
# Is Left: False, Is Right: False
# Line: slope=-0.8823529411764706, b=722.4117647058823, xbot=-269.2666666666667
# Is Left: False, Is Right: False
# Line: slope=0.5714285714285714, b=34.71428571428572, xbot=1619.25
# Is Left: False, Is Right: False
# Line: slope=0.6, b=13.199999999999989, xbot=1578.0
# Is Left: False, Is Right: False
# Line: slope=0.6721311475409836, b=-20.213114754098342, xbot=1458.3658536585367
# Is Left: False, Is Right: False
# Line: slope=0.6687898089171974, b=-16.554140127388507, xbot=1460.1809523809525
# Is Left: False, Is Right: False
# Line: slope=0.6246153846153846, b=6.203076923076935, xbot=1527.0147783251234
# Is Left: False, Is Right: False
# Line: slope=0.6287878787878788, b=2.5757575757575637, xbot=1522.6506024096386
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=630.3333333333333, xbot=-494.5000000000001
# Is Left: False, Is Right: False
# Line: slope=-0.7209302325581395, b=654.2558139534883, xbot=-424.0967741935485
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=630.0, xbot=-495.0
# Is Left: False, Is Right: False
# Line: slope=0.660377358490566, b=-10.30188679245282, xbot=1469.3142857142857
# Is Left: False, Is Right: False
# Line: slope=0.6607142857142857, b=-9.982142857142833, xbot=1468.0810810810813
# Is Left: False, Is Right: False
# Line: slope=-0.18181818181818182, b=553.3636363636364, xbot=-2236.5
# Is Left: False, Is Right: False
# Line: slope=-0.7058823529411765, b=648.7647058823529, xbot=-440.91666666666663
# Is Left: False, Is Right: False
# Line: slope=-0.6, b=601.2, xbot=-598.0
# Is Left: False, Is Right: False
# Line: slope=-0.7317073170731707, b=658.8780487804878, xbot=-411.53333333333336
# Is Left: False, Is Right: False
# Line: slope=-0.6896551724137931, b=636.448275862069, xbot=-469.15
# Is Left: False, Is Right: False
# Line: slope=0.6428571428571429, b=-10.35714285714289, xbot=1509.4444444444443
# Is Left: False, Is Right: False
# Line: slope=0.6732673267326733, b=-18.356435643564396, xbot=1453.1470588235293
# Is Left: False, Is Right: False
# Line: slope=0.5, b=103.0, xbot=1714.0
# Is Left: False, Is Right: False
# Line: slope=0.65625, b=-20.5625, xbot=1494.1904761904761
# Is Left: False, Is Right: False
# Line: slope=0.6571428571428571, b=-18.742857142857133, xbot=1489.391304347826
# Is Left: False, Is Right: False
# Line: slope=0.6551724137931034, b=-16.034482758620697, xbot=1489.7368421052631
# Is Left: False, Is Right: False
# Line: slope=0.6571428571428571, b=-20.542857142857088, xbot=1492.1304347826085
# Is Left: False, Is Right: False
# Line: slope=0.7, b=-45.39999999999998, xbot=1436.2857142857144
# Is Left: False, Is Right: False
# Line: slope=0.6739130434782609, b=-21.413043478260875, xbot=1456.2903225806451
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-29.66666666666663, xbot=1484.5
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-26.66666666666663, xbot=1480.0
# Is Left: False, Is Right: False
# Line: slope=0.7142857142857143, b=-48.85714285714289, xbot=1412.4
# Is Left: False, Is Right: False
# Line: slope=-0.73125, b=663.1875, xbot=-405.8974358974359
# Is Left: False, Is Right: False
# Line: slope=-0.7266187050359713, b=655.8057553956835, xbot=-418.64356435643555
# Is Left: False, Is Right: False
# Line: slope=-0.7164179104477612, b=650.5671641791045, xbot=-431.91666666666674
# Is Left: False, Is Right: False
# Line: slope=-0.6956521739130435, b=655.8695652173913, xbot=-437.18750000000006
# Is Left: False, Is Right: False
# Line: slope=-0.7142857142857143, b=651.5714285714286, xbot=-431.8
# Is Left: False, Is Right: False
# Line: slope=-0.7263157894736842, b=656.6842105263158, xbot=-417.6086956521738
# Is Left: False, Is Right: False
# Line: slope=0.5526315789473685, b=53.9210526315789, xbot=1639.5714285714284
# Is Left: False, Is Right: False
# Line: slope=0.5454545454545454, b=56.54545454545456, xbot=1656.3333333333335
# Is Left: False, Is Right: False
# Line: slope=0.6, b=23.400000000000034, xbot=1561.0
# Is Left: False, Is Right: False
# Line: slope=-0.74, b=665.12, xbot=-398.4864864864865
# Is Left: False, Is Right: False
# Line: slope=-0.6842105263157895, b=656.3684210526316, xbot=-443.7692307692308
# Is Left: False, Is Right: False
# Line: slope=-0.7, b=658.1, xbot=-431.2857142857143
# Is Left: False, Is Right: False
# Line: slope=-0.8461538461538461, b=672.8461538461538, xbot=-339.36363636363643
# Is Left: False, Is Right: False
# Line: slope=0.5853658536585366, b=38.6829268292683, xbot=1573.9166666666667
# Is Left: False, Is Right: False
# Line: slope=0.3, b=262.70000000000005, xbot=2324.3333333333335
# Is Left: False, Is Right: False
# Line: slope=-0.047619047619047616, b=528.7142857142857, xbot=-9057.000000000002
# Is Left: False, Is Right: False
# Line: slope=-0.71875, b=650.125, xbot=-431.1304347826087
# Is Left: False, Is Right: False
# Line: slope=0.5294117647058824, b=67.52941176470586, xbot=1685.7777777777778
# Is Left: False, Is Right: False
# Line: slope=0.5681818181818182, b=48.68181818181813, xbot=1603.9199999999998
# Is Left: False, Is Right: False
# Line: slope=-0.7142857142857143, b=650.7142857142858, xbot=-432.9999999999999
# Is Left: False, Is Right: False
# Line: slope=0.6363636363636364, b=4.0, xbot=1502.2857142857142
# Is Left: False, Is Right: False
# Line: slope=0.5, b=86.5, xbot=1747.0
# Is Left: False, Is Right: False
# Line: slope=-0.6923076923076923, b=657.2307692307693, xbot=-437.33333333333326
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=648.3333333333333, xbot=-467.5000000000001
# Is Left: False, Is Right: False
# Line: slope=-1.0, b=775.0, xbot=-185.0
# Is Left: False, Is Right: False
# Line: slope=-0.7857142857142857, b=684.8571428571429, xbot=-350.18181818181813
# Is Left: False, Is Right: False
# Line: slope=-0.7311827956989247, b=661.6451612903226, xbot=-408.04411764705884
# Is Left: False, Is Right: False
# Line: slope=-0.726027397260274, b=654.8904109589041, xbot=-420.2452830188679
# Is Left: False, Is Right: False
# Line: slope=0.6097560975609756, b=20.17073170731709, xbot=1541.32
# Is Left: False, Is Right: False
# Line: slope=0.575, b=35.450000000000045, xbot=1607.913043478261
# Is Left: False, Is Right: False
# Line: slope=-0.7647058823529411, b=671.4117647058823, xbot=-377.3846153846155
# Is Left: False, Is Right: False
# Line: slope=-0.7407407407407407, b=669.5925925925926, xbot=-392.05
# Is Left: False, Is Right: False
# Line: slope=0.6172839506172839, b=14.28395061728395, xbot=1532.0600000000002
# Is Left: False, Is Right: False
# Line: slope=-0.7450980392156863, b=669.0980392156863, xbot=-390.4210526315789
# Is Left: False, Is Right: False
# Line: slope=-0.7375, b=665.05, xbot=-399.93220338983053
# Is Left: False, Is Right: False
# Line: slope=-0.7397260273972602, b=666.4246575342465, xbot=-396.87037037037044
# Is Left: False, Is Right: False
# Line: slope=0.6111111111111112, b=12.833333333333314, xbot=1549.909090909091
# Is Left: False, Is Right: False
# Line: slope=0.5789473684210527, b=35.57894736842104, xbot=1596.7272727272727
# Is Left: False, Is Right: False
# Line: slope=0.62, b=11.100000000000023, xbot=1530.483870967742
# Is Left: False, Is Right: False
# Line: slope=0.625, b=6.5, xbot=1525.6
# Is Left: False, Is Right: False
# Line: slope=0.6111111111111112, b=16.27777777777777, xbot=1544.272727272727
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=651.6666666666666, xbot=-462.50000000000006
# Is Left: False, Is Right: False
# Line: slope=-0.7272727272727273, b=657.1818181818182, xbot=-416.3749999999999
# Is Left: False, Is Right: False
# Line: slope=0.0, b=445.0, xbot=inf
# Is Left: False, Is Right: False
# Line: slope=0.5789473684210527, b=33.52631578947364, xbot=1600.2727272727273
# Is Left: False, Is Right: False
# Line: slope=-0.7586206896551724, b=667.1379310344828, xbot=-386.0454545454545
# Is Left: False, Is Right: False
# Line: slope=-0.6875, b=660.375, xbot=-435.8181818181818
# Is Left: False, Is Right: False
# Line: slope=0.5625, b=41.8125, xbot=1632.3333333333333
# Is Left: False, Is Right: False
# Line: slope=-0.7647058823529411, b=670.2941176470588, xbot=-378.8461538461539
# Is Left: False, Is Right: False
# Line: slope=0.5714285714285714, b=39.14285714285717, xbot=1611.5000000000002
# Is Left: False, Is Right: False
# Line: slope=-0.7692307692307693, b=669.2307692307693, xbot=-377.9999999999999
# Is Left: False, Is Right: False
# Line: slope=-0.7, b=644.4, xbot=-450.85714285714295
# Is Left: False, Is Right: False
# Line: slope=0.09090909090909091, b=437.0, xbot=5753.0
# Is Left: False, Is Right: False
# Line: slope=-0.7857142857142857, b=675.5, xbot=-362.0909090909091
# Is Left: False, Is Right: False
# Line: slope=-0.7, b=655.8, xbot=-434.57142857142867
# Is Left: False, Is Right: False
# Line: slope=-0.8, b=683.2, xbot=-345.99999999999994
# Is Left: False, Is Right: False
# Line: slope=-0.9230769230769231, b=708.2307692307693, xbot=-272.74999999999994
# Is Left: False, Is Right: False
# Line: slope=-0.6779661016949152, b=632.6271186440678, xbot=-482.87500000000006
# Is Left: False, Is Right: False
# Line: slope=0.6304347826086957, b=7.652173913043441, xbot=1510.6206896551723
# Is Left: False, Is Right: False
# Line: slope=-0.7272727272727273, b=654.1818181818182, xbot=-420.4999999999999
# Is Left: False, Is Right: False
# Line: slope=0.6179775280898876, b=8.719101123595522, xbot=1539.3454545454547
# Is Left: False, Is Right: False
# Line: slope=-0.7058823529411765, b=638.1176470588235, xbot=-455.99999999999994
# Is Left: False, Is Right: False
# Line: slope=0.66, b=-13.879999999999995, xbot=1475.5757575757575
# Is Left: False, Is Right: False
# Line: slope=-0.7209302325581395, b=651.7906976744187, xbot=-427.51612903225805
# Is Left: False, Is Right: False
# Line: slope=-0.6904761904761905, b=635.8571428571429, xbot=-469.44827586206895
# Is Left: False, Is Right: False
# Line: slope=0.64, b=2.319999999999993, xbot=1496.375
# Is Left: False, Is Right: False
# Line: slope=-0.4166666666666667, b=520.1666666666667, xbot=-1055.5999999999997
# Is Left: False, Is Right: False
# Line: slope=0.6153846153846154, b=9.769230769230717, xbot=1544.125
# Is Left: False, Is Right: False
# Line: slope=0.6, b=18.80000000000001, xbot=1568.6666666666667
# Is Left: False, Is Right: False
# Line: slope=0.6875, b=-27.3125, xbot=1436.090909090909
# Is Left: False, Is Right: False
# Line: slope=-0.7096774193548387, b=638.1935483870968, xbot=-453.4545454545454
# Is Left: False, Is Right: False
# Line: slope=-0.68, b=631.0, xbot=-483.8235294117647
# Is Left: False, Is Right: False
# Line: slope=-0.7096774193548387, b=639.3548387096774, xbot=-451.81818181818176
# Is Left: False, Is Right: False
# Line: slope=-0.8333333333333334, b=669.0, xbot=-349.2
# Is Left: False, Is Right: False
# Line: slope=-0.7333333333333333, b=646.8666666666667, xbot=-427.0
# Is Left: False, Is Right: False
# Line: slope=0.7272727272727273, b=-61.90909090909088, xbot=1405.125
# Is Left: False, Is Right: False
# Line: slope=0.6190476190476191, b=9.23809523809524, xbot=1535.8461538461538
# Is Left: False, Is Right: False
# Line: slope=-0.7058823529411765, b=640.6470588235295, xbot=-452.4166666666665
# Is Left: False, Is Right: False
# Line: slope=-0.6521739130434783, b=622.3913043478261, xbot=-517.6666666666666
# Is Left: False, Is Right: False
# Line: slope=0.6923076923076923, b=-29.0, xbot=1428.5555555555557
# Is Left: False, Is Right: False
# Line: slope=-0.75, b=653.0, xbot=-409.3333333333333
# Is Left: False, Is Right: False
# Line: slope=0.6111111111111112, b=12.499999999999943, xbot=1550.4545454545453
# Is Left: False, Is Right: False
# Line: slope=-0.25, b=482.5, xbot=-1910.0
# Is Left: False, Is Right: False
# Line: slope=0.0, b=424.0, xbot=inf
# Is Left: False, Is Right: False
# Line: slope=-0.7096774193548387, b=640.483870967742, xbot=-450.2272727272727
# Is Left: False, Is Right: False
# Line: slope=-0.7647058823529411, b=659.0588235294117, xbot=-393.53846153846166
# Is Left: False, Is Right: False
# Line: slope=0.5833333333333334, b=41.66666666666663, xbot=1574.2857142857142
# Is Left: False, Is Right: False
# Line: slope=0.6, b=16.400000000000034, xbot=1572.6666666666665
# Is Left: False, Is Right: False
# Line: slope=-0.6428571428571429, b=614.8571428571429, xbot=-536.8888888888888
# Is Left: False, Is Right: False
# Line: slope=0.625, b=12.375, xbot=1516.2
# Is Left: False, Is Right: False
# Line: slope=-0.7333333333333333, b=647.4666666666667, xbot=-426.1818181818182
# Is Left: False, Is Right: False
# Line: slope=-1.4285714285714286, b=921.8571428571429, xbot=-26.699999999999978
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=627.3333333333333, xbot=-499.0000000000001
# Is Left: False, Is Right: False
# Line: slope=-0.8125, b=689.625, xbot=-332.7692307692308
# Is Left: False, Is Right: False
# Line: slope=0.6363636363636364, b=4.181818181818187, xbot=1502.0
# Is Left: False, Is Right: False
# Line: slope=-0.625, b=618.75, xbot=-546.0
# Is Left: False, Is Right: False
# Line: slope=-0.7267441860465116, b=663.9418604651163, xbot=-407.37600000000003
# Is Left: False, Is Right: False
# Line: slope=-0.7818181818181819, b=689.6727272727273, xbot=-345.767441860465
# Is Left: False, Is Right: False
# Line: slope=-0.735632183908046, b=671.0344827586207, xbot=-392.8125
# Is Left: False, Is Right: False
# Line: slope=0.6125, b=11.012499999999989, xbot=1549.3673469387754
# Is Left: False, Is Right: False
# Line: slope=0.6, b=16.80000000000001, xbot=1572.0000000000002
# Is Left: False, Is Right: False
# Line: slope=0.6176470588235294, b=5.9705882352940876, xbot=1544.6190476190475
# Is Left: False, Is Right: False
# Line: slope=0.5686274509803921, b=36.117647058823536, xbot=1624.7586206896551
# Is Left: False, Is Right: False
# Line: slope=-0.7339449541284404, b=666.9266055045872, xbot=-399.31249999999994
# Is Left: False, Is Right: False
# Line: slope=0.6, b=20.80000000000001, xbot=1565.3333333333335
# Is Left: False, Is Right: False
# Line: slope=-0.7407407407407407, b=672.5555555555555, xbot=-388.05
# Is Left: False, Is Right: False
# Line: slope=0.5409836065573771, b=59.852459016393425, xbot=1663.909090909091
# Is Left: False, Is Right: False
# Line: slope=-0.7321428571428571, b=664.9285714285714, xbot=-403.0243902439024
# Is Left: False, Is Right: False
# Line: slope=0.5882352941176471, b=24.882352941176464, xbot=1589.7
# Is Left: False, Is Right: False
# Line: slope=-0.42857142857142855, b=505.42857142857144, xbot=-1060.6666666666667
# Is Left: False, Is Right: False
# Line: slope=-0.7441860465116279, b=675.7441860465117, xbot=-381.96874999999994
# Is Left: False, Is Right: False
# Line: slope=0.6521739130434783, b=-18.565217391304373, xbot=1500.4666666666667
# Is Left: False, Is Right: False
# Line: slope=-0.4, b=495.6, xbot=-1160.9999999999998
# Is Left: False, Is Right: False
# Line: slope=-0.6896551724137931, b=657.8275862068965, xbot=-438.15000000000003
# Is Left: False, Is Right: False
# Line: slope=0.5925925925925926, b=26.0, xbot=1576.125
# Is Left: False, Is Right: False
# Line: slope=0.5454545454545454, b=57.00000000000006, xbot=1655.5000000000002
# Is Left: False, Is Right: False
# Line: slope=-0.6923076923076923, b=659.4615384615385, xbot=-434.11111111111114
# Is Left: False, Is Right: False
# Line: slope=-0.6153846153846154, b=587.3846153846154, xbot=-605.5
# Is Left: False, Is Right: False
# Line: slope=0.6666666666666666, b=-43.66666666666663, xbot=1505.5
# Is Left: False, Is Right: False
# Line: slope=-0.5714285714285714, b=647.0, xbot=-547.75
# Is Left: False, Is Right: False
# Line: slope=0.5789473684210527, b=34.05263157894734, xbot=1599.3636363636365
# Is Left: False, Is Right: False
# Line: slope=0.5294117647058824, b=68.8235294117647, xbot=1683.3333333333335
# Is Left: False, Is Right: False
# Line: slope=0.0, b=487.0, xbot=inf
# Is Left: False, Is Right: False
# Line: slope=-0.6, b=643.2, xbot=-528.0
# Is Left: False, Is Right: False
# Line: slope=-0.75, b=678.25, xbot=-375.6666666666667
# Is Left: False, Is Right: False
# Line: slope=-0.2727272727272727, b=441.1818181818182, xbot=-1902.3333333333333
# Is Left: False, Is Right: False
# Line: slope=0.5555555555555556, b=46.77777777777777, xbot=1643.7999999999997
# Is Left: False, Is Right: False
# Line: slope=-0.6785714285714286, b=656.0357142857143, xbot=-447.94736842105254
# Is Left: False, Is Right: False
# Line: slope=-0.7586206896551724, b=682.0344827586207, xbot=-366.40909090909093
# Is Left: False, Is Right: False
# Line: slope=-0.6666666666666666, b=655.0, xbot=-457.5
# Is Left: False, Is Right: False
# Line: slope=-0.7391304347826086, b=673.1304347826087, xbot=-388.1176470588235
# Is Left: False, Is Right: False
# Line: slope=-0.7, b=659.8, xbot=-428.85714285714295
# Is Left: False, Is Right: False
# Line: slope=0.18181818181818182, b=328.9090909090909, xbot=3471.0
# Is Left: False, Is Right: False

# %%
#reading in an image
image = mpimg.imread('test_images_output/whiteCarLaneSwitch.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
# Out:
# Imageio: 'ffmpeg-win32-v3.2.4.exe' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-win32-v3.2.4.exe (34.1 MB)
# Downloading: 8192/35749888 bytes (0.0253952/35749888 bytes (0.7704512/35749888 bytes (2.01187840/35749888 bytes (3.3%1671168/35749888 bytes (4.7%2162688/35749888 bytes (6.0%2654208/35749888 bytes (7.4%3112960/35749888 bytes (8.7%3563520/35749888 bytes (10.04022272/35749888 bytes (11.34538368/35749888 bytes (12.75046272/35749888 bytes (14.15529600/35749888 bytes (15.56004736/35749888 bytes (16.86520832/35749888 bytes (18.27012352/35749888 bytes (19.67487488/35749888 bytes (20.97987200/35749888 bytes (22.38454144/35749888 bytes (23.68986624/35749888 bytes (25.19502720/35749888 bytes (26.610027008/35749888 bytes (28.0%10518528/35749888 bytes (29.4%11026432/35749888 bytes (30.8%11534336/35749888 bytes (32.3%12017664/35749888 bytes (33.6%12509184/35749888 bytes (35.0%13033472/35749888 bytes (36.5%13516800/35749888 bytes (37.8%14024704/35749888 bytes (39.2%14565376/35749888 bytes (40.7%15106048/35749888 bytes (42.3%15613952/35749888 bytes (43.7%16130048/35749888 bytes (45.1%16613376/35749888 bytes (46.5%17121280/35749888 bytes (47.9%17620992/35749888 bytes (49.3%18145280/35749888 bytes (50.8%18694144/35749888 bytes (52.3%19243008/35749888 bytes (53.8%19750912/35749888 bytes (55.2%20242432/35749888 bytes (56.6%20733952/35749888 bytes (58.0%21241856/35749888 bytes (59.4%21766144/35749888 bytes (60.9%22249472/35749888 bytes (62.2%22749184/35749888 bytes (63.6%23248896/35749888 bytes (65.0%23756800/35749888 bytes (66.5%24289280/35749888 bytes (67.9%24797184/35749888 bytes (69.4%25305088/35749888 bytes (70.8%25804800/35749888 bytes (72.2%26312704/35749888 bytes (73.6%26836992/35749888 bytes (75.1%27336704/35749888 bytes (76.5%27811840/35749888 bytes (77.8%28319744/35749888 bytes (79.2%28819456/35749888 bytes (80.6%29327360/35749888 bytes (82.0%29835264/35749888 bytes (83.5%30351360/35749888 bytes (84.9%30859264/35749888 bytes (86.3%31350784/35749888 bytes (87.7%31834112/35749888 bytes (89.0%32309248/35749888 bytes (90.4%32808960/35749888 bytes (91.8%33300480/35749888 bytes (93.1%33792000/35749888 bytes (94.5%34291712/35749888 bytes (95.9%34750464/35749888 bytes (97.2%35274752/35749888 bytes (98.7%35749888/35749888 bytes (100.0%)
#   Done
# File saved as C:\Users\user\AppData\Local\imageio\ffmpeg\ffmpeg-win32-v3.2.4.exe.

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result = draw_lane_lines(image)
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
# 100%|███████████████████████████████████████████████████████████████████████████████▋| 221/222 [00:03<00:00, 63.31it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# Wall time: 3.94 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
# 100%|███████████████████████████████████████████████████████████████████████████████▉| 681/682 [00:11<00:00, 60.64it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidYellowLeft.mp4
#
# Wall time: 11.7 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
# 100%|████████████████████████████████████████████████████████████████████████████████| 251/251 [00:16<00:00, 16.91it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/challenge.mp4
#
# Wall time: 17.2 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/challenge.mp4">
# </video>
